# %% [markdown]
# # EXP 3: Histogram-of-an-images

# %% [markdown]
# # NAME :HARISH S

# %% [markdown]
# # REG NO : 212224040105

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('harish.png')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
hist_original = cv2.calcHist([gray_image], [0], None, [256], [0, 256])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 image = cv2.imread('harish.png')
#       2 gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       3 hist_original = cv2.calcHist([gray_image], [0], None, [256], [0, 256])
#
# NameError: name 'cv2' is not defined

# %%
equalized_image = cv2.equalizeHist(gray_image)
hist_equalized = cv2.calcHist([equalized_image], [0], None, [256], [0, 256])
plt.figure(figsize=(10, 7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 equalized_image = cv2.equalizeHist(gray_image)
#       2 hist_equalized = cv2.calcHist([equalized_image], [0], None, [256], [0, 256])
#       3 plt.figure(figsize=(10, 7))
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# plt.subplot(2, 2, 1)
# plt.imshow(gray_image, cmap='gray')
# plt.title('Original Grayscale Image')
# plt.axis('off')

# %%
plt.subplot(2, 2, 2)
plt.imshow(equalized_image, cmap='gray')
plt.title('Equalized Image')
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.subplot(2, 2, 2)
#       2 plt.imshow(equalized_image, cmap='gray')
#       3 plt.title('Equalized Image')
#
# NameError: name 'plt' is not defined

# %%
plt.subplot(2, 2, 3)
plt.plot(hist_original, color='black')
plt.title('Original Histogram')
plt.xlim([0, 256])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.subplot(2, 2, 3)
#       2 plt.plot(hist_original, color='black')
#       3 plt.title('Original Histogram')
#
# NameError: name 'plt' is not defined

# %%
plt.subplot(2, 2, 4)
plt.plot(hist_equalized, color='black')
plt.title('Equalized Histogram')
plt.xlim([0, 256])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.subplot(2, 2, 4)
#       2 plt.plot(hist_equalized, color='black')
#       3 plt.title('Equalized Histogram')
#
# NameError: name 'plt' is not defined

# %%
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.tight_layout()
#       2 plt.show()
#
# NameError: name 'plt' is not defined
